# %%
# %load_ext autoreload
# %autoreload 2
import yaml
import pandas as pd
# from pandas.core.common import SettingWithCopyWarning
pd.options.mode.chained_assignment = None
# import warnings
# warnings.simplefilter(action='ignore', category=SettingWithCopyWarning)
import numpy as np
import os
opj = os.path.join
opd = os.path.dirname
import glob
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit
from scipy.stats import norm
from utils import *
from analyse import *

Z = norm.ppf

# %%
out='0_ses-0_task-2afc_run-4' 
beh = AnalyseTrialRun(out)
beh.plot_stairs()
# beh.analyseYesNo()
# Out:
# small
# small :  0.5712290228462705
# large_low
# large_low :  0.6076492112063876
# large_high
# large_high :  0.6066582103731424
# /data1/projects/dumoulinlab/Projects/packages/envs/postproc/lib/python3.9/site-packages/psychopy/data/fit.py:114: RuntimeWarning: invalid value encountered in power
#   np.exp(-(xx/alpha)**beta))
